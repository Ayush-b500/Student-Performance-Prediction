# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush-b500/Student-Performance-Prediction/blob/main/01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Ayush-b500/Student-Performance-Prediction.git
# Out:
# Cloning into 'Student-Performance-Prediction'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 5.54 KiB | 1.85 MiB/s, done.

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

data = {
    "study_hours": np.random.randint(1, 10, 50),
    "attendance": np.random.randint(50, 100, 50),
    "previous_score": np.random.randint(40, 90, 50),
}

df = pd.DataFrame(data)

# target column
df["final_score"] = (
    df["study_hours"] * 5 +
    df["attendance"] * 0.3 +
    df["previous_score"] * 0.5
)

df.head()
# Out:
#    study_hours  attendance  previous_score  final_score
# 0            7          53              78         89.9
# 1            4          51              80         75.3
# 2            8          55              67         90.0
# 3            5          91              46         75.3
# 4            7          53              48         74.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   study_hours     50 non-null     int64
#  1   attendance      50 non-null     int64
#  2   previous_score  50 non-null     int64
#  3   final_score     50 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 1.7 KB

# %%
df.describe()
# Out:
#        study_hours  attendance  previous_score  final_score
# count    50.000000   50.000000        50.00000    50.000000
# mean      5.200000   72.480000        65.64000    80.564000
# std       2.490799   14.508604        13.99965    14.538531
# min       1.000000   50.000000        40.00000    51.600000
# 25%       3.000000   59.250000        53.25000    70.125000
# 50%       5.000000   73.000000        67.50000    78.700000
# 75%       7.000000   84.000000        77.50000    89.850000
# max       9.000000   97.000000        88.00000   116.900000

# %%
df.isnull().sum()
# Out:
# study_hours       0
# attendance        0
# previous_score    0
# final_score       0
# dtype: int64

# %%
# %cd Student-Performance-Prediction/
# Out:
# /content/Student-Performance-Prediction

# %%
# !ls
# Out:
# 01.ipynb  README.md

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git config --global user.email "ayushsarangi320@gmail.com"
# !git config --global user.name "Ayush-b500"

# %%
# !git commit -m "Added my notebook"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(df["study_hours"], df["final_score"])
plt.xlabel("Study Hours")
plt.ylabel("Final Score")
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()
